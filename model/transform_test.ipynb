# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets import load_dataset

# %%
from data import ImageDataset
from train import image_transform, reverse_transform

# %%
d = load_dataset("skvarre/movie_posters")
# Out:
# ...
# Generating train split: 100%|██████████| 9955/9955 [00:07<00:00, 1400.22 examples/s]

# %%
d["train"][0]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x750>

# %%
ds = ImageDataset(10)

# %%
batch = ds[0]
reverse_transform(image_transform(batch))
# Out:
# <PIL.Image.Image image mode=RGB size=128x192>
